# %%
# Example Usage with the @job decorator
scheduler = JobScheduler(use_threading=False)





"""     Second-based Job        """
# Example 1.1: Runs Every 2 Seconds Until a Certain Time
second_job = Job().every(2).second.until("2024-08-10 20:48").do(report1, job_name="Every 2 Seconds")
scheduler.add_job(second_job)




# Example 2.0: Runs Every 2 Seconds, Repeating 3 Times
@jobs(interval=2, unit='second', repeat=3)
def report2(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 2.1: Runs Every 2 Seconds, Repeating 3 Times
second_job = Job().every(3).second.repeat(3).do(report2, job_name="Every 2 Seconds")
scheduler.add_job(second_job)




"""     Minute-based Job        """

# Example 3.0: Runs Every Minute Until a Certain Time
@jobs(interval=1, unit='minute', until="2024-08-10 20:48")
def report3(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 3.1: Runs Every Minute Until a Certain Time
minute_job = Job().every(1).minute.until("2024-08-10 20:48").do(report3, job_name="Every 2 Minutes Until")
scheduler.add_job(minute_job)




# Example 4.0: Runs Every Minute, Repeating 3 Times
@jobs(interval=1, unit='minute', repeat=3)
def report4(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 4.1: Runs Every Minute, Repeating 3 Times
minute_job = Job().every(1).minute.repeat(3).do(report4, job_name="Every 2 Minutes Until")
scheduler.add_job(minute_job)




"""     Minute-based Job        """

# Example 5.0: Runs Every Hour Until a Certain Time
@jobs(interval=1, unit='hour', until="2024-08-10 20:48")
def report5(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 5.1: Runs Every Hour Until a Certain Time
hourly_job = Job().every(1).hour.until("2024-08-10 20:48").do(report5, job_name="Hourly Report")
scheduler.add_job(hourly_job)




# Example 6.0: Runs Every Hour, Repeating 3 Times
@jobs(interval=1, unit='hour', repeat=3)
def report6(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 6.1: Runs Every Hour, Repeating 3 Times
hourly_job = Job().every(1).hour.repeat(3).do(report6, job_name="Hourly Report")
scheduler.add_job(hourly_job)




"""     Daily Job        """

# Example 7.0: Runs Every Day at 09:00  Until a Certain Time
@jobs(interval=1, unit='day', time_at='09:00', until="2024-08-10 20:48")
def report7(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 7.1: Runs Every Day at 09:00  Until a Certain Time
alternate_day_job = Job().every(1).day.at(time_at='09:00').until("2024-08-10 20:48").do(report7, job_name="Alternate Day Report")
scheduler.add_job(alternate_day_job)




# Example 8.0: Runs Every Day at 09:00, Repeating 3 Times
@jobs(interval=1, unit='day', time_at='09:00', repeat=3)
def report8(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 8.1: Runs Every Day at 09:00, Repeating 3 Times
alternate_day_job = Job().every(1).day.at(time_at='09:00').repeat(3).do(report8, job_name="Alternate Day Report")
scheduler.add_job(alternate_day_job)




"""     Weekly Job        """

# Example 9.0: Runs Every Monday at 09:00 Until a Certain Date
@jobs(interval=1, unit='week', time_at='09:00', until="2024-08-10 15:48")
def report9(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 9.1: Runs Every Monday at 09:00 Until a Certain Date
weekly_job = Job().every(1).week(weekday=0, time_at='09:00').until("2024-08-10 15:48").do(report9, job_name="Weekly Report")
scheduler.add_job(weekly_job)




# Example 10.0: Runs Every Monday at 09:00, Repeating 3 Times
@jobs(interval=1, unit='week', time_at='09:00', repeat=3)
def report10(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 10.1: Runs Every Monday at 09:00, Repeating 3 Times
weekly_job = Job().every(1).week(weekday=0, time_at='09:00').repeat(3).do(report10, job_name="Weekly Report")
scheduler.add_job(weekly_job)




"""     Monthly Job        """

# Example 11.0: Runs Every 15th of Month at 09:00  Until a Certain Date
@jobs(interval=1, unit='month', time_at='09:00', until="2024-08-10 15:48")
def report11(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 11.1: Runs Every 15th of Month at 09:00  Until a Certain Date
monthly_job = Job().every(1).month(day=15, time_at='09:00').until("2024-08-10 15:48").do(report11, job_name="Monthly Report")
scheduler.add_job(monthly_job)




# Example 12.0: Runs Every 15th of Month at 09:00, Repeating 3 Times
@jobs(interval=1, unit='month', time_at='09:00', repeat=3)
def report12(job_name):
    print(f"Running {job_name} at {datetime.now()}")


# Example 12.1: Runs Every 15th of Month at 09:00, Repeating 3 Times
monthly_job = Job().every(1).month(day=15, time_at='09:00').repeat(3).do(report12, job_name="Monthly Report")
scheduler.add_job(monthly_job)




"""     Yearly Job        """

# Example 13.0: Runs on November 15th at 09:00 Until a Certain Date
@jobs(interval=1, unit='year', time_at='09:00', until="2024-08-10 15:48")
def report13(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 13.0: Runs on November 15th at 09:00 Until a Certain Date
yearly_job = Job().every(1).year(month=11, day=15, time_at='09:00').until("2024-08-10 15:48").do(report13, job_name="Yearly Report")
scheduler.add_job(yearly_job)


# Example 14.0: Runs on November 15th at 09:00, Repeating 3 Times
@jobs(interval=1, unit='year', time_at='09:00', repeat=3)
def report14(job_name):
    print(f"Running {job_name} at {datetime.now()}")

# Example 14.1: Runs on November 15th at 09:00, Repeating 3 Times
yearly_job = Job().every(1).year(month=11, day=15, time_at='09:00').repeat(3).do(report14, job_name="Yearly Report")
scheduler.add_job(yearly_job)





# Start the scheduler
scheduler.run_pending()
